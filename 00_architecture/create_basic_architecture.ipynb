-- %% [markdown]
-- # Create basic architecture needed for the medallion architecture

-- %%
CREATE CATALOG IF NOT EXISTS uniswap;

-- %%
CREATE SCHEMA IF NOT EXISTS uniswap.orchestrator;
CREATE SCHEMA IF NOT EXISTS uniswap.bronze;
CREATE SCHEMA IF NOT EXISTS uniswap.silver;
CREATE SCHEMA IF NOT EXISTS uniswap.gold;
