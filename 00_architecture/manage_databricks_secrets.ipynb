# %%
pip install databricks-cli

# %%
import os

os.environ['DATABRICKS_HOST'] = "PASTE YOUR DATABRICKS HOST URL HERE"
os.environ['DATABRICKS_TOKEN'] = dbutils.notebook.entry_point.getDbutils().notebook().getContext().apiToken().get()

# %%
# !databricks secrets create-scope --scope subgraph-api-secrets

# %%
# !databricks secrets list-scopes

# %%
# !databricks secrets put --scope subgraph-api-secrets --key api-key --string-value "PASTE YOUR API KEY HERE"

# %%
# !databricks secrets put --scope subgraph-api-secrets --key subgraph-id --string-value "5zvR82QoaXYFyDEKLZ9t6v9adgnptxYpKpSbxtgVENFV"

# %%
# !databricks secrets list --scope subgraph-api-secrets
