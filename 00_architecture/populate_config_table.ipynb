-- %% [markdown]
-- Configuration table schema:
-- + layer: str
-- + entity_name: str
-- + active_for_load: boolean
-- + priority: int
-- + load_pattern: int
-- + notebook_path: str

-- %%
INSERT INTO IDENTIFIER(:config_table_path)
VALUES
-- Bronze entities
("bronze", "factory", True, 1, 2, "../01_bronze/factory_extract"),
("bronze", "pools", True, 1, 2, "../01_bronze/pools_extract"),
("bronze", "tokens", True, 1, 2, "../01_bronze/tokens_extract"),
("bronze", "ticks", True, 2, 2, "../01_bronze/ticks_extract"),
("bronze", "swaps", True, 2, 2, "../01_bronze/swaps_extract"),
("bronze", "mints", True, 2, 2, "../01_bronze/mints_extract"),
("bronze", "burns", True, 2, 2, "../01_bronze/burns_extract"),
("bronze", "positions", True, 2, 2, "../01_bronze/positions_extract"),
-- Silver entities
("silver", "factory", True, 1, 1, "../02_silver/factory_transform"),
("silver", "pools", True, 1, 1, "../02_silver/pools_transform"),
("silver", "tokens", True, 1, 1, "../02_silver/tokens_transform"),
("silver", "ticks", True, 2, 1, "../02_silver/ticks_transform"),
("silver", "swaps", True, 2, 1, "../02_silver/swaps_transform"),
("silver", "mints", True, 2, 1, "../02_silver/mints_transform"),
("silver", "burns", True, 2, 1, "../02_silver/burns_transform"),
("silver", "positions", True, 2, 1, "../02_silver/positions_transform"),
-- Gold entities
("gold", "pools", True, 1, 1, "../03_gold/dim_pools"),
("gold", "tokens", True, 1, 1, "../03_gold/dim_tokens"),
("gold", "positions", True, 1, 1, "../03_gold/dim_positions"),
("gold", "swaps", True, 1, 1, "../03_gold/fact_swaps"),
("gold", "liquidity_events", True, 1, 1, "../03_gold/fact_liquidity_events")
