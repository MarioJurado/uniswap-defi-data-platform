-- %%
INSERT INTO IDENTIFIER(:config_table_path)
VALUES
("bronze", "factory", True, 1, 1, "../01_bronze/factory_extr"),
("bronze", "pools", True, 1, 2, "../01_bronze/pools_extr"),
("bronze", "tokens", True, 1, 2, "../01_bronze/tokens_extr"),
("bronze", "ticks", True, 2, 2, "../01_bronze/ticks_extr"),
("bronze", "swaps", True, 2, 2, "../01_bronze/swaps_extr"),
("silver", "pools", True, 1, 1, "../02_silver/pools_transf"),
("silver", "tokens", True, 1, 1, "../02_silver/tokens_transf")
